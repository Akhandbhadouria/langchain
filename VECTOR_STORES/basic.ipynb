# %%
# !pip install langchain chromadb openai tiktoken pypdf langchain_openai langchain-community
# Out:
# Collecting langchain
#   Downloading langchain-1.3.11-py3-none-any.whl.metadata (6.0 kB)
# Collecting chromadb
#   Downloading chromadb-1.5.9-cp39-abi3-macosx_11_0_arm64.whl.metadata (5.0 kB)
# Collecting openai
#   Downloading openai-2.44.0-py3-none-any.whl.metadata (34 kB)
# Collecting tiktoken
#   Downloading tiktoken-0.13.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (6.7 kB)
# Collecting pypdf
#   Downloading pypdf-6.14.2-py3-none-any.whl.metadata (7.2 kB)
# Collecting langchain_openai
#   Downloading langchain_openai-1.3.3-py3-none-any.whl.metadata (3.4 kB)
# WARNING: Cache entry deserialization failed, entry ignored
# Collecting langchain-community
#   Downloading langchain_community-0.4.2-py3-none-any.whl.metadata (3.4 kB)
# Collecting langchain-core<2.0.0,>=1.4.7 (from langchain)
#   Downloading langchain_core-1.4.8-py3-none-any.whl.metadata (4.7 kB)
# Collecting langgraph<1.3.0,>=1.2.5 (from langchain)
#   Downloading langgraph-1.2.6-py3-none-any.whl.metadata (4.9 kB)
# Collecting pydantic<3.0.0,>=2.7.4 (from langchain)
#   Using cached pydantic-2.13.4-py3-none-any.whl.metadata (109 kB)
# Collecting build>=1.0.3 (from chromadb)
#   Downloading build-1.5.0-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: pydantic-settings>=2.0 in /opt/anaconda3/lib/python3.12/site-packages (from chromadb) (2.6.1)
# Collecting pybase64>=1.4.1 (from chromadb)
#   Downloading pybase64-1.4.3-cp312-cp312-macosx_11_0_arm64.whl.metadata (8.7 kB)
# Collecting uvicorn>=0.18.3 (from uvicorn[standard]>=0.18.3->chromadb)
#   Downloading uvicorn-0.49.0-py3-none-any.whl.metadata (6.7 kB)
# Requirement already satisfied: numpy>=1.22.5 in /opt/anaconda3/lib/python3.12/site-packages (from chromadb) (1.26.4)
# Requirement already satisfied: typing-extensions>=4.5.0 in /opt/anaconda3/lib/python3.12/site-packages (from chromadb) (4.11.0)
# Collecting onnxruntime>=1.14.1 (from chromadb)
#   Downloading onnxruntime-1.27.0-cp312-cp312-macosx_14_0_arm64.whl.metadata (5.4 kB)
# Collecting opentelemetry-api>=1.2.0 (from chromadb)
#   Downloading opentelemetry_api-1.43.0-py3-none-any.whl.metadata (1.4 kB)
# Collecting opentelemetry-exporter-otlp-proto-grpc>=1.2.0 (from chromadb)
#   Downloading opentelemetry_exporter_otlp_proto_grpc-1.43.0-py3-none-any.whl.metadata (2.6 kB)
# Collecting opentelemetry-sdk>=1.2.0 (from chromadb)
#   Downloading opentelemetry_sdk-1.43.0-py3-none-any.whl.metadata (1.7 kB)
# WARNING: Cache entry deserialization failed, entry ignored
# Collecting tokenizers>=0.13.2 (from chromadb)
#   Using cached tokenizers-0.23.1-cp310-abi3-macosx_11_0_arm64.whl.metadata (9.8 kB)
# Collecting pypika>=0.48.9 (from chromadb)
#   Using cached pypika-0.51.1-py2.py3-none-any.whl.metadata (51 kB)
# Requirement already satisfied: tqdm>=4.65.0 in /opt/anaconda3/lib/python3.12/site-packages (from chromadb) (4.66.5)
# Requirement already satisfied: overrides>=7.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from chromadb) (7.4.0)
# Collecting importlib-resources (from chromadb)
#   Using cached importlib_resources-7.1.0-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: grpcio>=1.58.0 in /opt/anaconda3/lib/python3.12/site-packages (from chromadb) (1.71.0)
# Collecting bcrypt>=4.0.1 (from chromadb)
#   Using cached bcrypt-5.0.0-cp39-abi3-macosx_10_12_universal2.whl.metadata (10 kB)
# Requirement already satisfied: typer>=0.9.0 in /opt/anaconda3/lib/python3.12/site-packages (from chromadb) (0.24.1)
# Collecting kubernetes>=28.1.0 (from chromadb)
#   Downloading kubernetes-36.0.2-py2.py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: tenacity>=8.2.3 in /opt/anaconda3/lib/python3.12/site-packages (from chromadb) (8.2.3)
# Requirement already satisfied: pyyaml>=6.0.0 in /opt/anaconda3/lib/python3.12/site-packages (from chromadb) (6.0.1)
# Collecting mmh3>=4.0.1 (from chromadb)
#   Downloading mmh3-5.2.1-cp312-cp312-macosx_11_0_arm64.whl.metadata (14 kB)
# Requirement already satisfied: orjson>=3.9.12 in /opt/anaconda3/lib/python3.12/site-packages (from chromadb) (3.11.9)
# Requirement already satisfied: httpx>=0.27.0 in /opt/anaconda3/lib/python3.12/site-packages (from chromadb) (0.27.0)
# Requirement already satisfied: rich>=10.11.0 in /opt/anaconda3/lib/python3.12/site-packages (from chromadb) (13.7.1)
# Requirement already satisfied: jsonschema>=4.19.0 in /opt/anaconda3/lib/python3.12/site-packages (from chromadb) (4.23.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /opt/anaconda3/lib/python3.12/site-packages (from openai) (4.2.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /opt/anaconda3/lib/python3.12/site-packages (from openai) (1.9.0)
# Collecting jiter<1,>=0.10.0 (from openai)
#   Downloading jiter-0.15.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (5.2 kB)
# Requirement already satisfied: sniffio in /opt/anaconda3/lib/python3.12/site-packages (from openai) (1.3.0)
# Collecting typing-extensions>=4.5.0 (from chromadb)
#   Using cached typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: regex in /opt/anaconda3/lib/python3.12/site-packages (from tiktoken) (2024.9.11)
# Requirement already satisfied: requests in /opt/anaconda3/lib/python3.12/site-packages (from tiktoken) (2.32.3)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /opt/anaconda3/lib/python3.12/site-packages (from langchain-community) (3.10.5)
# Collecting httpx-sse<1.0.0,>=0.4.0 (from langchain-community)
#   Using cached httpx_sse-0.4.3-py3-none-any.whl.metadata (9.7 kB)
# Collecting langchain-classic<2.0.0,>=1.0.7 (from langchain-community)
#   Downloading langchain_classic-1.0.8-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: langsmith<1.0.0,>=0.1.125 in /opt/anaconda3/lib/python3.12/site-packages (from langchain-community) (0.1.147)
# Collecting pydantic-settings>=2.0 (from chromadb)
#   Downloading pydantic_settings-2.14.2-py3-none-any.whl.metadata (3.4 kB)
# Collecting requests (from tiktoken)
#   Using cached requests-2.34.2-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: sqlalchemy<3.0.0,>=1.4.0 in /opt/anaconda3/lib/python3.12/site-packages (from langchain-community) (2.0.34)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /opt/anaconda3/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/anaconda3/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in /opt/anaconda3/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/anaconda3/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/anaconda3/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/anaconda3/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.11.0)
# Requirement already satisfied: idna>=2.8 in /opt/anaconda3/lib/python3.12/site-packages (from anyio<5,>=3.5.0->openai) (3.7)
# Requirement already satisfied: packaging>=24.0 in /opt/anaconda3/lib/python3.12/site-packages (from build>=1.0.3->chromadb) (24.1)
# Collecting pyproject_hooks (from build>=1.0.3->chromadb)
#   Using cached pyproject_hooks-1.2.0-py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: certifi in /opt/anaconda3/lib/python3.12/site-packages (from httpx>=0.27.0->chromadb) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in /opt/anaconda3/lib/python3.12/site-packages (from httpx>=0.27.0->chromadb) (1.0.2)
# Requirement already satisfied: h11<0.15,>=0.13 in /opt/anaconda3/lib/python3.12/site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb) (0.14.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/anaconda3/lib/python3.12/site-packages (from jsonschema>=4.19.0->chromadb) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/anaconda3/lib/python3.12/site-packages (from jsonschema>=4.19.0->chromadb) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /opt/anaconda3/lib/python3.12/site-packages (from jsonschema>=4.19.0->chromadb) (0.10.6)
# Requirement already satisfied: six>=1.9.0 in /opt/anaconda3/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in /opt/anaconda3/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb) (2.9.0.post0)
# Collecting pyyaml>=6.0.0 (from chromadb)
#   Downloading pyyaml-6.0.3-cp312-cp312-macosx_11_0_arm64.whl.metadata (2.4 kB)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /opt/anaconda3/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb) (1.8.0)
# Collecting requests-oauthlib (from kubernetes>=28.1.0->chromadb)
#   Using cached requests_oauthlib-2.0.0-py2.py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: urllib3!=2.6.0,>=1.24.2 in /opt/anaconda3/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb) (2.2.3)
# Collecting durationpy>=0.7 (from kubernetes>=28.1.0->chromadb)
#   Using cached durationpy-0.10-py3-none-any.whl.metadata (340 bytes)
# WARNING: Cache entry deserialization failed, entry ignored
# Collecting aiohttp<4.0.0,>=3.8.3 (from langchain-community)
#   Downloading aiohttp-3.14.1-cp312-cp312-macosx_11_0_arm64.whl.metadata (8.3 kB)
# WARNING: Cache entry deserialization failed, entry ignored
# Collecting aiohappyeyeballs>=2.5.0 (from aiohttp<4.0.0,>=3.8.3->langchain-community)
#   Using cached aiohappyeyeballs-2.6.2-py3-none-any.whl.metadata (5.9 kB)
# WARNING: Cache entry deserialization failed, entry ignored
# Collecting aiosignal>=1.4.0 (from aiohttp<4.0.0,>=3.8.3->langchain-community)
#   Using cached aiosignal-1.4.0-py3-none-any.whl.metadata (3.7 kB)
# WARNING: Cache entry deserialization failed, entry ignored
# Collecting propcache>=0.2.0 (from aiohttp<4.0.0,>=3.8.3->langchain-community)
#   Downloading propcache-0.5.2-cp312-cp312-macosx_11_0_arm64.whl.metadata (16 kB)
# WARNING: Cache entry deserialization failed, entry ignored
# Collecting yarl<2.0,>=1.17.0 (from aiohttp<4.0.0,>=3.8.3->langchain-community)
#   Downloading yarl-1.24.2-cp312-cp312-macosx_11_0_arm64.whl.metadata (94 kB)
# Collecting langchain-text-splitters<2.0.0,>=1.1.2 (from langchain-classic<2.0.0,>=1.0.7->langchain-community)
#   Using cached langchain_text_splitters-1.1.2-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /opt/anaconda3/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.4.7->langchain) (1.33)
# Collecting langchain-protocol>=0.0.17 (from langchain-core<2.0.0,>=1.4.7->langchain)
#   Downloading langchain_protocol-0.0.18-py3-none-any.whl.metadata (2.4 kB)
# Collecting langsmith<1.0.0,>=0.1.125 (from langchain-community)
#   Downloading langsmith-0.9.1-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /opt/anaconda3/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.4.7->langchain) (0.15.0)
# Collecting langgraph-checkpoint<5.0.0,>=4.1.0 (from langgraph<1.3.0,>=1.2.5->langchain)
#   Downloading langgraph_checkpoint-4.1.1-py3-none-any.whl.metadata (5.2 kB)
# Collecting langgraph-prebuilt<1.2.0,>=1.1.0 (from langgraph<1.3.0,>=1.2.5->langchain)
#   Using cached langgraph_prebuilt-1.1.0-py3-none-any.whl.metadata (5.2 kB)
# Collecting langgraph-sdk<0.5.0,>=0.4.2 (from langgraph<1.3.0,>=1.2.5->langchain)
#   Downloading langgraph_sdk-0.4.2-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: xxhash>=3.5.0 in /opt/anaconda3/lib/python3.12/site-packages (from langgraph<1.3.0,>=1.2.5->langchain) (3.7.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /opt/anaconda3/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (1.0.0)
# Collecting websockets>=15.0 (from langsmith<1.0.0,>=0.1.125->langchain-community)
#   Downloading websockets-16.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (6.8 kB)
# Requirement already satisfied: zstandard>=0.23.0 in /opt/anaconda3/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (0.23.0)
# Requirement already satisfied: flatbuffers in /opt/anaconda3/lib/python3.12/site-packages (from onnxruntime>=1.14.1->chromadb) (25.2.10)
# Collecting protobuf>=4.25.8 (from onnxruntime>=1.14.1->chromadb)
#   Downloading protobuf-7.35.1-cp310-abi3-macosx_10_9_universal2.whl.metadata (595 bytes)
# WARNING: Cache entry deserialization failed, entry ignored
# Collecting googleapis-common-protos~=1.57 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb)
#   Using cached googleapis_common_protos-1.75.0-py3-none-any.whl.metadata (8.6 kB)
# Collecting opentelemetry-exporter-otlp-proto-common==1.43.0 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb)
#   Downloading opentelemetry_exporter_otlp_proto_common-1.43.0-py3-none-any.whl.metadata (1.8 kB)
# Collecting opentelemetry-proto==1.43.0 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb)
#   Downloading opentelemetry_proto-1.43.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting opentelemetry-semantic-conventions==0.64b0 (from opentelemetry-sdk>=1.2.0->chromadb)
#   Downloading opentelemetry_semantic_conventions-0.64b0-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/anaconda3/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.6.0)
# Collecting pydantic-core==2.46.4 (from pydantic<3.0.0,>=2.7.4->langchain)
#   Downloading pydantic_core-2.46.4-cp312-cp312-macosx_11_0_arm64.whl.metadata (6.6 kB)
# Collecting typing-inspection>=0.4.2 (from pydantic<3.0.0,>=2.7.4->langchain)
#   Using cached typing_inspection-0.4.2-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: python-dotenv>=0.21.0 in /opt/anaconda3/lib/python3.12/site-packages (from pydantic-settings>=2.0->chromadb) (0.21.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/anaconda3/lib/python3.12/site-packages (from requests->tiktoken) (3.3.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/anaconda3/lib/python3.12/site-packages (from rich>=10.11.0->chromadb) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/anaconda3/lib/python3.12/site-packages (from rich>=10.11.0->chromadb) (2.15.1)
# WARNING: Cache entry deserialization failed, entry ignored
# Collecting huggingface-hub<2.0,>=0.16.4 (from tokenizers>=0.13.2->chromadb)
#   Downloading huggingface_hub-1.20.1-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: click>=8.2.1 in /opt/anaconda3/lib/python3.12/site-packages (from typer>=0.9.0->chromadb) (8.3.1)
# Requirement already satisfied: shellingham>=1.3.0 in /opt/anaconda3/lib/python3.12/site-packages (from typer>=0.9.0->chromadb) (1.5.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in /opt/anaconda3/lib/python3.12/site-packages (from typer>=0.9.0->chromadb) (0.0.4)
# Collecting httptools>=0.8.0 (from uvicorn[standard]>=0.18.3->chromadb)
#   Downloading httptools-0.8.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (3.5 kB)
# Collecting uvloop>=0.15.1 (from uvicorn[standard]>=0.18.3->chromadb)
#   Downloading uvloop-0.22.1-cp312-cp312-macosx_10_13_universal2.whl.metadata (4.9 kB)
# Collecting watchfiles>=0.20 (from uvicorn[standard]>=0.18.3->chromadb)
#   Downloading watchfiles-1.2.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (4.9 kB)
# Collecting click>=8.2.1 (from typer>=0.9.0->chromadb)
#   Downloading click-8.4.2-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: filelock>=3.10.0 in /opt/anaconda3/lib/python3.12/site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/anaconda3/lib/python3.12/site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (2024.6.1)
# WARNING: Cache entry deserialization failed, entry ignored
# Collecting hf-xet<2.0.0,>=1.5.1 (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb)
#   Downloading hf_xet-1.5.1-cp37-abi3-macosx_11_0_arm64.whl.metadata (4.9 kB)
# Requirement already satisfied: jsonpointer>=1.9 in /opt/anaconda3/lib/python3.12/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.4.7->langchain) (2.1)
# Collecting ormsgpack>=1.12.0 (from langgraph-checkpoint<5.0.0,>=4.1.0->langgraph<1.3.0,>=1.2.5->langchain)
#   Downloading ormsgpack-1.12.2-cp312-cp312-macosx_10_12_x86_64.macosx_11_0_arm64.macosx_10_12_universal2.whl.metadata (3.2 kB)
# Collecting websockets>=15.0 (from langsmith<1.0.0,>=0.1.125->langchain-community)
#   Downloading websockets-15.0.1-cp312-cp312-macosx_11_0_arm64.whl.metadata (6.8 kB)
# Requirement already satisfied: mdurl~=0.1 in /opt/anaconda3/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb) (0.1.0)
# Collecting oauthlib>=3.0.0 (from requests-oauthlib->kubernetes>=28.1.0->chromadb)
#   Using cached oauthlib-3.3.1-py3-none-any.whl.metadata (7.9 kB)
# Downloading langchain-1.3.11-py3-none-any.whl (133 kB)
# Downloading chromadb-1.5.9-cp39-abi3-macosx_11_0_arm64.whl (21.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.7/21.7 MB 3.3 MB/s eta 0:00:0000:0100:01
# Downloading openai-2.44.0-py3-none-any.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 5.1 MB/s eta 0:00:00a 0:00:01
# Downloading tiktoken-0.13.0-cp312-cp312-macosx_11_0_arm64.whl (982 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 983.0/983.0 kB 3.1 MB/s eta 0:00:00a 0:00:01
# Downloading pypdf-6.14.2-py3-none-any.whl (349 kB)
# Downloading langchain_openai-1.3.3-py3-none-any.whl (120 kB)
# Downloading langchain_community-0.4.2-py3-none-any.whl (2.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 3.9 MB/s eta 0:00:0000:0100:01
# Using cached bcrypt-5.0.0-cp39-abi3-macosx_10_12_universal2.whl (495 kB)
# Downloading build-1.5.0-py3-none-any.whl (26 kB)
# Using cached httpx_sse-0.4.3-py3-none-any.whl (9.0 kB)
# Downloading jiter-0.15.0-cp312-cp312-macosx_11_0_arm64.whl (309 kB)
# Downloading kubernetes-36.0.2-py2.py3-none-any.whl (4.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 4.3 MB/s eta 0:00:00a 0:00:01
# Downloading aiohttp-3.14.1-cp312-cp312-macosx_11_0_arm64.whl (512 kB)
# Downloading langchain_classic-1.0.8-py3-none-any.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 3.2 MB/s eta 0:00:00a 0:00:01
# Downloading langchain_core-1.4.8-py3-none-any.whl (557 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 557.4/557.4 kB 3.0 MB/s eta 0:00:00
# Downloading langgraph-1.2.6-py3-none-any.whl (246 kB)
# Downloading langsmith-0.9.1-py3-none-any.whl (578 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 578.9/578.9 kB 6.6 MB/s eta 0:00:00
# Downloading mmh3-5.2.1-cp312-cp312-macosx_11_0_arm64.whl (40 kB)
# Downloading onnxruntime-1.27.0-cp312-cp312-macosx_14_0_arm64.whl (18.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.4/18.4 MB 4.6 MB/s eta 0:00:00a 0:00:01
# Downloading opentelemetry_api-1.43.0-py3-none-any.whl (61 kB)
# Downloading opentelemetry_exporter_otlp_proto_grpc-1.43.0-py3-none-any.whl (19 kB)
# Downloading opentelemetry_exporter_otlp_proto_common-1.43.0-py3-none-any.whl (17 kB)
# Downloading opentelemetry_proto-1.43.0-py3-none-any.whl (72 kB)
# Downloading opentelemetry_sdk-1.43.0-py3-none-any.whl (178 kB)
# Downloading opentelemetry_semantic_conventions-0.64b0-py3-none-any.whl (203 kB)
# Downloading pybase64-1.4.3-cp312-cp312-macosx_11_0_arm64.whl (31 kB)
# Using cached pydantic-2.13.4-py3-none-any.whl (472 kB)
# Downloading pydantic_core-2.46.4-cp312-cp312-macosx_11_0_arm64.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 4.1 MB/s eta 0:00:00a 0:00:01
# Downloading pydantic_settings-2.14.2-py3-none-any.whl (61 kB)
# Using cached pypika-0.51.1-py2.py3-none-any.whl (60 kB)
# Downloading pyyaml-6.0.3-cp312-cp312-macosx_11_0_arm64.whl (173 kB)
# Using cached requests-2.34.2-py3-none-any.whl (73 kB)
# Using cached tokenizers-0.23.1-cp310-abi3-macosx_11_0_arm64.whl (3.1 MB)
# Using cached typing_extensions-4.15.0-py3-none-any.whl (44 kB)
# Downloading uvicorn-0.49.0-py3-none-any.whl (71 kB)
# Using cached importlib_resources-7.1.0-py3-none-any.whl (37 kB)
# Using cached aiohappyeyeballs-2.6.2-py3-none-any.whl (15 kB)
# Using cached aiosignal-1.4.0-py3-none-any.whl (7.5 kB)
# Using cached durationpy-0.10-py3-none-any.whl (3.9 kB)
# Using cached googleapis_common_protos-1.75.0-py3-none-any.whl (300 kB)
# Downloading httptools-0.8.0-cp312-cp312-macosx_11_0_arm64.whl (113 kB)
# Downloading huggingface_hub-1.20.1-py3-none-any.whl (719 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 719.8/719.8 kB 6.0 MB/s eta 0:00:00
# Downloading click-8.4.2-py3-none-any.whl (119 kB)
# Downloading langchain_protocol-0.0.18-py3-none-any.whl (7.2 kB)
# Using cached langchain_text_splitters-1.1.2-py3-none-any.whl (35 kB)
# Downloading langgraph_checkpoint-4.1.1-py3-none-any.whl (56 kB)
# Using cached langgraph_prebuilt-1.1.0-py3-none-any.whl (41 kB)
# Downloading langgraph_sdk-0.4.2-py3-none-any.whl (160 kB)
# Downloading propcache-0.5.2-cp312-cp312-macosx_11_0_arm64.whl (55 kB)
# Downloading protobuf-7.35.1-cp310-abi3-macosx_10_9_universal2.whl (433 kB)
# Using cached typing_inspection-0.4.2-py3-none-any.whl (14 kB)
# Downloading uvloop-0.22.1-cp312-cp312-macosx_10_13_universal2.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 1.5 MB/s eta 0:00:00a 0:00:01
# Downloading watchfiles-1.2.0-cp312-cp312-macosx_11_0_arm64.whl (393 kB)
# Downloading websockets-15.0.1-cp312-cp312-macosx_11_0_arm64.whl (173 kB)
# Downloading yarl-1.24.2-cp312-cp312-macosx_11_0_arm64.whl (91 kB)
# Using cached pyproject_hooks-1.2.0-py3-none-any.whl (10 kB)
# Using cached requests_oauthlib-2.0.0-py2.py3-none-any.whl (24 kB)
# Downloading hf_xet-1.5.1-cp37-abi3-macosx_11_0_arm64.whl (3.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 5.2 MB/s eta 0:00:00a 0:00:01
# Using cached oauthlib-3.3.1-py3-none-any.whl (160 kB)
# Downloading ormsgpack-1.12.2-cp312-cp312-macosx_10_12_x86_64.macosx_11_0_arm64.macosx_10_12_universal2.whl (378 kB)
# Installing collected packages: pypika, durationpy, websockets, uvloop, typing-extensions, requests, pyyaml, pyproject_hooks, pypdf, pybase64, protobuf, propcache, ormsgpack, oauthlib, mmh3, jiter, importlib-resources, httpx-sse, httptools, hf-xet, click, bcrypt, aiohappyeyeballs, yarl, watchfiles, uvicorn, typing-inspection, tiktoken, requests-oauthlib, pydantic-core, opentelemetry-proto, opentelemetry-api, onnxruntime, langchain-protocol, googleapis-common-protos, build, aiosignal, pydantic, opentelemetry-semantic-conventions, opentelemetry-exporter-otlp-proto-common, aiohttp, pydantic-settings, opentelemetry-sdk, openai, langsmith, kubernetes, huggingface-hub, tokenizers, opentelemetry-exporter-otlp-proto-grpc, langchain-core, langgraph-sdk, langgraph-checkpoint, langchain-text-splitters, langchain_openai, chromadb, langgraph-prebuilt, langchain-classic, langgraph, langchain-community, langchain
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.11.0
#     Uninstalling typing_extensions-4.11.0:
#       Successfully uninstalled typing_extensions-4.11.0
#   Attempting uninstall: requests
#     Found existing installation: requests 2.32.3
#     Uninstalling requests-2.32.3:
#       Successfully uninstalled requests-2.32.3
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 6.0.1
#     Uninstalling PyYAML-6.0.1:
#       Successfully uninstalled PyYAML-6.0.1
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 4.25.3
#     Uninstalling protobuf-4.25.3:
#       Successfully uninstalled protobuf-4.25.3
#   Attempting uninstall: click
#     Found existing installation: click 8.3.1
#     Uninstalling click-8.3.1:
#       Successfully uninstalled click-8.3.1
#   Attempting uninstall: bcrypt
#     Found existing installation: bcrypt 3.2.0
#     Uninstalling bcrypt-3.2.0:
#       Successfully uninstalled bcrypt-3.2.0
#   Attempting uninstall: aiohappyeyeballs
#     Found existing installation: aiohappyeyeballs 2.4.0
#     Uninstalling aiohappyeyeballs-2.4.0:
#       Successfully uninstalled aiohappyeyeballs-2.4.0
#   Attempting uninstall: yarl
#     Found existing installation: yarl 1.11.0
#     Uninstalling yarl-1.11.0:
#       Successfully uninstalled yarl-1.11.0
#   Attempting uninstall: pydantic-core
#     Found existing installation: pydantic_core 2.20.1
#     Uninstalling pydantic_core-2.20.1:
#       Successfully uninstalled pydantic_core-2.20.1
#   Attempting uninstall: langchain-protocol
#     Found existing installation: langchain-protocol 0.0.15
#     Uninstalling langchain-protocol-0.0.15:
#       Successfully uninstalled langchain-protocol-0.0.15
#   Attempting uninstall: aiosignal
#     Found existing installation: aiosignal 1.2.0
#     Uninstalling aiosignal-1.2.0:
#       Successfully uninstalled aiosignal-1.2.0
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 1.10.26
#     Uninstalling pydantic-1.10.26:
#       Successfully uninstalled pydantic-1.10.26
#   Attempting uninstall: aiohttp
#     Found existing installation: aiohttp 3.10.5
#     Uninstalling aiohttp-3.10.5:
#       Successfully uninstalled aiohttp-3.10.5
#   Attempting uninstall: pydantic-settings
#     Found existing installation: pydantic-settings 2.6.1
#     Uninstalling pydantic-settings-2.6.1:
#       Successfully uninstalled pydantic-settings-2.6.1
#   Attempting uninstall: langsmith
#     Found existing installation: langsmith 0.1.147
#     Uninstalling langsmith-0.1.147:
#       Successfully uninstalled langsmith-0.1.147
#   Attempting uninstall: langchain-core
#     Found existing installation: langchain-core 0.2.43
#     Uninstalling langchain-core-0.2.43:
#       Successfully uninstalled langchain-core-0.2.43
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gtts 2.5.4 requires click<8.2,>=7.1, but you have click 8.4.2 which is incompatible.
# mediapipe 0.10.21 requires protobuf<5,>=4.25.3, but you have protobuf 7.35.1 which is incompatible.
# tensorflow 2.19.0 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3, but you have protobuf 7.35.1 which is incompatible.
# streamlit 1.37.1 requires protobuf<6,>=3.20, but you have protobuf 7.35.1 which is incompatible.
# langchain-groq 0.1.10 requires langchain-core<0.3.0,>=0.2.39, but you have langchain-core 1.4.8 which is incompatible.
# Successfully installed aiohappyeyeballs-2.6.2 aiohttp-3.14.1 aiosignal-1.4.0 bcrypt-5.0.0 build-1.5.0 chromadb-1.5.9 click-8.4.2 durationpy-0.10 googleapis-common-protos-1.75.0 hf-xet-1.5.1 httptools-0.8.0 httpx-sse-0.4.3 huggingface-hub-1.20.1 importlib-resources-7.1.0 jiter-0.15.0 kubernetes-36.0.2 langchain-1.3.11 langchain-classic-1.0.8 langchain-community-0.4.2 langchain-core-1.4.8 langchain-protocol-0.0.18 langchain-text-splitters-1.1.2 langchain_openai-1.3.3 langgraph-1.2.6 langgraph-checkpoint-4.1.1 langgraph-prebuilt-1.1.0 langgraph-sdk-0.4.2 langsmith-0.9.1 mmh3-5.2.1 oauthlib-3.3.1 onnxruntime-1.27.0 openai-2.44.0 opentelemetry-api-1.43.0 opentelemetry-exporter-otlp-proto-common-1.43.0 opentelemetry-exporter-otlp-proto-grpc-1.43.0 opentelemetry-proto-1.43.0 opentelemetry-sdk-1.43.0 opentelemetry-semantic-conventions-0.64b0 ormsgpack-1.12.2 propcache-0.5.2 protobuf-7.35.1 pybase64-1.4.3 pydantic-2.13.4 pydantic-core-2.46.4 pydantic-settings-2.14.2 pypdf-6.14.2 pypika-0.51.1 pyproject_hooks-1.2.0 pyyaml-6.0.3 requests-2.34.2 requests-oauthlib-2.0.0 tiktoken-0.13.0 tokenizers-0.23.1 typing-extensions-4.15.0 typing-inspection-0.4.2 uvicorn-0.49.0 uvloop-0.22.1 watchfiles-1.2.0 websockets-15.0.1 yarl-1.24.2

# %%
from langchain_openai import OpenAIEmbeddings 
from langchain_chroma import Chroma

# %%
from langchain.schema import Document

# Create LangChain documents for IPL players

doc1 = Document(
        page_content="Virat Kohli is one of the most successful and consistent batsmen in IPL history. Known for his aggressive batting style and fitness, he has led the Royal Challengers Bangalore in multiple seasons.",
        metadata={"team": "Royal Challengers Bangalore"}
    )
doc2 = Document(
        page_content="Rohit Sharma is the most successful captain in IPL history, leading Mumbai Indians to five titles. He's known for his calm demeanor and ability to play big innings under pressure.",
        metadata={"team": "Mumbai Indians"}
    )
doc3 = Document(
        page_content="MS Dhoni, famously known as Captain Cool, has led Chennai Super Kings to multiple IPL titles. His finishing skills, wicketkeeping, and leadership are legendary.",
        metadata={"team": "Chennai Super Kings"}
    )
doc4 = Document(
        page_content="Jasprit Bumrah is considered one of the best fast bowlers in T20 cricket. Playing for Mumbai Indians, he is known for his yorkers and death-over expertise.",
        metadata={"team": "Mumbai Indians"}
    )
doc5 = Document(
        page_content="Ravindra Jadeja is a dynamic all-rounder who contributes with both bat and ball. Representing Chennai Super Kings, his quick fielding and match-winning performances make him a key player.",
        metadata={"team": "Chennai Super Kings"}
    )

# %%
docs = [doc1, doc2, doc3, doc4, doc5]

# %%
vector_store = Chroma(
    embedding_function=OpenAIEmbeddings(),
    persist_directory='my_chroma_db',
    collection_name='sample'
)

# %%
# add documents
vector_store.add_documents(docs)

# %%
# view documents
vector_store.get(include=['embeddings','documents', 'metadatas'])

# %%
# search documents
vector_store.similarity_search(
    query='Who among these are a bowler?',
    k=2
)
